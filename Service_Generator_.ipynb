# %% [markdown]
# <a href="https://colab.research.google.com/github/Khyati2542/Khyati_project-/blob/main/Service_Generator_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #install required liabraries

# %%
# !pip install langchain
# !pip install langchain-community
# !pip install sentence_transformers
# !pip install PyPDF2
# Out:
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
# ...

# %%
import os
from langchain.chains import RetrievalQA
from langchain.prompts import ChatPromptTemplate
from langchain.document_loaders import TextLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
import google.generativeai as genai
from sentence_transformers import SentenceTransformer

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
import PyPDF2

# %% [markdown]
# # Load Sentence Transformer Model

# %%
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %%
import os
import google.generativeai as genai # Make sure to import the module

# os.environ["GEMINI_API_KEY"] = "AIzaSyDTtCaNmd-cXEy1dh6qcaCzNkl0moLfg0s"
# genai.configure(api_key=os.environ['GEMINI_API_KEY'])
API_KEY = "GOOGLE_API_KEY"
genai.configure(api_key=API_KEY) # Configure the API key using genai.configure()
client = genai.GenerativeModel() # Call Gemini from the genai module

# %% [markdown]
# #read pdf file

# %%
def load_pdf(path):
  """Loads text from a PDF file.

  Args:
    path: Path to the PDF file.

  Returns:
    A string containing the text content of the PDF file.
  """
  with open(path, 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    text = ""
    for page_num in range(len(reader.pages)):
      page = reader.pages[page_num]
      text += page.extract_text()
    return text

pdf_text = load_pdf("/content/service_generation_topic.pdf")
print(pdf_text)
# Out:
# 1. Order Management Service (E -commerce)
# Description : A service to create an order, track its status, and manage order updates.
# Key Requirements :
# • Create Order : Accept user details, product list, and payment information.
# • Validation : Ensure that products are in stock, user information is correct, and payment is
# authorized.
# • Order Tracking : Allow users to query order status (e.g., pending, shipped, delivered).
# • Error Handling : Return meaningful errors for stock shortages, invalid payment details, or
# incomplete orders.
# • Logging : Log order creation and updates, including any errors encountered.
# • Security : Encrypt sensitive user data (e.g., payment details) and implement access control.
# • Technology Stack : REST API with endpoints like POST /orders , GET /orders/{id} , database
# integration for order storage.
#
# 2. Appointment Scheduling Service (Healthcare)
# Description : A service to schedule, cancel, and update patient appointments.
# ...

# %%
def extract_text_from_pdf(pdf_document):
    """
    Extracts text from a PDF file.

    Parameters:
        pdf_document (str): The path to the PDF file.

    Returns:
        str: The extracted text from the PDF.
    """
    try:
        with open(pdf_document, 'rb') as pdf_file:
            reader = PyPDF2.PdfReader(pdf_file)
            text = ""

            for page_num in range(len(reader.pages)):
                page = reader.pages[page_num]
                text += page.extract_text() or ""

            return text

    except FileNotFoundError:
        print(f"Error: The file '{pdf_document}' was not found.")
        return ""
    except Exception as e:
        print(f"An error occurred: {e}")
        return ""

# %%
# Function to split text into chunks
def split_text_into_chunks(text):
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=10,
        chunk_overlap=2,
        separators=["."]
    )
    chunks = splitter.split_text(text)

    return chunks

# Example
pdf_document = "/content/service_generation_topic.pdf" # Define pdf_document with the path to your PDF file
extracted_text = extract_text_from_pdf(pdf_document)

if extracted_text:
    chunks = split_text_into_chunks(extracted_text)

    print(f"Number of chunks: {len(chunks)}")

    for chunk in chunks:
        print(chunk)
        print("---\n")
# Out:
# Number of chunks: 56
# 1
# ---
#
# . Order Management Service (E -commerce)
# Description : A service to create an order, track its status, and manage order updates
# ---
#
# .
# Key Requirements :
# • Create Order : Accept user details, product list, and payment information
# ---
#
# .
# • Validation : Ensure that products are in stock, user information is correct, and payment is
# authorized
# ---
#
# .
# • Order Tracking : Allow users to query order status (e
# ---
#
# .g
# ---
#
# ., pending, shipped, delivered)
# ---
#
# .
# • Error Handling : Return meaningful errors for stock shortages, invalid payment details, or
# incomplete orders
# ---
#
# .
# • Logging : Log order creation and updates, including any errors encountered
# ---
#
# .
# • Security : Encrypt sensitive user data (e
# ---
#
# .g
# ---
#
# ., payment details) and implement access control
# ---
#
# .
# • Technology Stack : REST API with endpoints like POST /orders , GET /orders/{id} , database
# ...

# %%
output_file = 'sentences.txt'
with open(output_file, 'w') as file:
    for sentence in chunks:
        file.write(sentence + '\n')

print(f"Sentences have been saved to {output_file}")
# Out:
# Sentences have been saved to sentences.txt

# %%
embeddings = model.encode(chunks)

# %%
embeddings.shape
# Out:
# (56, 384)

# %%
# !pip install faiss-cpu
import faiss
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 61.0 MB/s eta 0:00:00
# ...

# %%
index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)

# Save the index
faiss.write_index(index, 'faiss_index.index')

# %%
question= input("Ask the model=>")
# Out:
# Ask the model=>Order Management Service (E-commerce)

# %%
query_embedding = model.encode([question])

# %%
import numpy as np

# %%
k = 5
D, I = index.search(np.array(query_embedding), k)

# Retrieve and print the results
print(f"Top {k} nearest sentences:")
for i in range(k):
    bunched_sentence = " ".join(chunks[I[0][i]])
    print(f"Sentence {i+1}: {chunks[I[0][i]]}, Distance: {D[0][i]}")
    print("__________"*20)
# Out:
# Top 5 nearest sentences:
# Sentence 1: . Order Management Service (E -commerce)
# Description : A service to create an order, track its status, and manage order updates, Distance: 0.1942642629146576
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# Sentence 2: . Inventory Management Service (Retail)
# Description : A service to track product inventory, update stock levels, and manage suppliers, Distance: 0.7188897132873535
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# Sentence 3: .
# Key Requirements :
# • Create Order : Accept user details, product list, and payment information, Distance: 0.9512720108032227
# ...

# %%
prefix = "Write a code in python using the details given in Context"
# Out:
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
# ...

# %%
prompt = f'''{prefix}\n\n\
                  Question: {question}\n\
                  Context: Purpose: General Service for E-commerce: This service manages customer orders, streamlining the process from order placement to fulfillment.\n\
                  Stored Information: \n\
                  - Order Details: Order ID, product IDs, quantities, total price, and order status.\n\
                  - Customer Information: User ID, name, email, shipping address, and payment details.\n\
                  - Shipping Information: Shipping method, tracking number, and estimated delivery date.\n\
                  Specific Functionalities:\n\
                  - Order Placement: Allows customers to place new orders.\n\
                  - Order Cancellation: Enables users to cancel orders before fulfillment.\n\
                  - Order Fulfillment: Updates order status as it progresses through shipping and delivery.\n\
                  - Order Tracking: Customers can track their orders and receive notifications about status changes.\n\
                  - Inventory Management: Automatically adjusts stock levels based on order placements and cancellations.\n\
                  Response: '''
# Out:
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
# ...

# %%
# !pip install -Uq "google-generativeai>=0.7.2"

# %%
import google.generativeai as genai
genai.__version__
# Out:
# '0.7.2'

# %%
from google.colab import userdata
genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))
# Out:
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>

# %%
from IPython.display import HTML, Markdown

def set_css_in_cell_output(unused):
  display(HTML("""<style>
div.output_markdown {
  font-size: 16px
}

div.output_markdown pre code {
  color: #222222;
}

div.output_markdown pre:nth-of-type(even) {
  background: #CCCCCC;
  margin: 16px;
  padding: 16px;
}

div.output_markdown pre:nth-of-type(odd) {
  background: #BBBBEE;
  margin: 16px;
  padding: 16px;
}
</style>"""))

get_ipython().events.register('pre_run_cell', set_css_in_cell_output)
# Out:
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
# ...

# %%
model = genai.GenerativeModel(model_name='gemini-1.5-flash', tools="code_execution")
# Out:
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
# ...

# %%
result = model.generate_content(prompt)
# Out:
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
# ...

# %%
[
    list(type(p).to_dict(p))
    for p in result.candidates[0].content.parts
]
# Out:
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
# ...

# %%
for part in result.candidates[0].content.parts:
  print(part)
  print()
# Out:
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
# ...

# %%
print(result.text)
# Out:
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
# ...

# %%
from IPython.display import Markdown
Markdown(result.text)
# Out:
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
#   background: #BBBBEE;
#   margin: 16px;
#   padding: 16px;
# }
# </style>
# <style>
# div.output_markdown {
#   font-size: 16px
# }
#
# div.output_markdown pre code {
#   color: #222222;
# }
#
# div.output_markdown pre:nth-of-type(even) {
#   background: #CCCCCC;
#   margin: 16px;
#   padding: 16px;
# }
#
# div.output_markdown pre:nth-of-type(odd) {
# ...
