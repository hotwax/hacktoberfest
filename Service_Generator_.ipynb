# %% [markdown]
# <a href="https://colab.research.google.com/github/Khyati2542/Khyati_project-/blob/main/Service_Generator_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #install required liabraries

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 871.9 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.8/401.8 kB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 38.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# !pip install sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 6.4 MB/s eta 0:00:00
# ...

# %%
# !pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.9 MB/s eta 0:00:00
# ...

# %%
import os
from langchain.chains import RetrievalQA
from langchain.prompts import ChatPromptTemplate
from langchain.document_loaders import TextLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
import google.generativeai as genai
from sentence_transformers import SentenceTransformer

# %% [markdown]
# # Load Sentence Transformer Model

# %%
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %%
import os
import google.generativeai as genai # Make sure to import the module

# os.environ["GEMINI_API_KEY"] = "AIzaSyDTtCaNmd-cXEy1dh6qcaCzNkl0moLfg0s"
# genai.configure(api_key=os.environ['GEMINI_API_KEY'])
API_KEY = "GOOGLE_API_KEY"
genai.configure(api_key=API_KEY) # Configure the API key using genai.configure()
client = genai.GenerativeModel() # Call Gemini from the genai module

# %%
import PyPDF2

# %% [markdown]
# #read pdf file

# %%
def load_pdf(path):
  """Loads text from a PDF file.

  Args:
    path: Path to the PDF file.

  Returns:
    A string containing the text content of the PDF file.
  """
  with open(path, 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    text = ""
    for page_num in range(len(reader.pages)):
      page = reader.pages[page_num]
      text += page.extract_text()
    return text

pdf_text = load_pdf("/content/service_generation_topic.pdf")
print(pdf_text)
# Out:
# 1. Order Management Service (E -commerce)
# Description : A service to create an order, track its status, and manage order updates.
# Key Requirements :
# • Create Order : Accept user details, product list, and payment information.
# • Validation : Ensure that products are in stock, user information is correct, and payment is
# authorized.
# • Order Tracking : Allow users to query order status (e.g., pending, shipped, delivered).
# • Error Handling : Return meaningful errors for stock shortages, invalid payment details, or
# incomplete orders.
# • Logging : Log order creation and updates, including any errors encountered.
# • Security : Encrypt sensitive user data (e.g., payment details) and implement access control.
# • Technology Stack : REST API with endpoints like POST /orders , GET /orders/{id} , database
# integration for order storage.
#
# 2. Appointment Scheduling Service (Healthcare)
# Description : A service to schedule, cancel, and update patient appointments.
# ...

# %%
def extract_text_from_pdf(pdf_document):
    """
    Extracts text from a PDF file.

    Parameters:
        pdf_document (str): The path to the PDF file.

    Returns:
        str: The extracted text from the PDF.
    """
    try:
        with open(pdf_document, 'rb') as pdf_file:
            reader = PyPDF2.PdfReader(pdf_file)
            text = ""

            for page_num in range(len(reader.pages)):
                page = reader.pages[page_num]
                text += page.extract_text() or ""

            return text

    except FileNotFoundError:
        print(f"Error: The file '{pdf_document}' was not found.")
        return ""
    except Exception as e:
        print(f"An error occurred: {e}")
        return ""

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# Function to split text into chunks
def split_text_into_chunks(text):
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=10,
        chunk_overlap=2,
        separators=["."]
    )
    chunks = splitter.split_text(text)

    return chunks

# Example
pdf_document = "/content/service_generation_topic.pdf" # Define pdf_document with the path to your PDF file
extracted_text = extract_text_from_pdf(pdf_document)

if extracted_text:
    chunks = split_text_into_chunks(extracted_text)

    print(f"Number of chunks: {len(chunks)}")

    for chunk in chunks:
        print(chunk)
        print("---\n")
# Out:
# Number of chunks: 56
# 1
# ---
#
# . Order Management Service (E -commerce)
# Description : A service to create an order, track its status, and manage order updates
# ---
#
# .
# Key Requirements :
# • Create Order : Accept user details, product list, and payment information
# ---
#
# .
# • Validation : Ensure that products are in stock, user information is correct, and payment is
# authorized
# ---
#
# .
# • Order Tracking : Allow users to query order status (e
# ---
#
# .g
# ---
#
# ., pending, shipped, delivered)
# ---
#
# .
# • Error Handling : Return meaningful errors for stock shortages, invalid payment details, or
# incomplete orders
# ---
#
# .
# • Logging : Log order creation and updates, including any errors encountered
# ---
#
# .
# • Security : Encrypt sensitive user data (e
# ---
#
# .g
# ---
#
# ., payment details) and implement access control
# ---
#
# .
# • Technology Stack : REST API with endpoints like POST /orders , GET /orders/{id} , database
# ...

# %%
output_file = 'sentences.txt'
with open(output_file, 'w') as file:
    for sentence in chunks:
        file.write(sentence + '\n')

print(f"Sentences have been saved to {output_file}")
# Out:
# Sentences have been saved to sentences.txt

# %%
embeddings = model.encode(chunks)

# %%
embeddings.shape
# Out:
# (56, 384)

# %%
# !pip install faiss-cpu
import faiss
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 62.0 MB/s eta 0:00:00
# ...

# %%
index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)

# Save the index
faiss.write_index(index, 'faiss_index.index')

# %%
question= input("Ask the model=>")
# Out:
# Ask the model=>Order Management Service (E-commerce)

# %%
query_embedding = model.encode([question])

# %%
import numpy as np

# %%
k = 5
D, I = index.search(np.array(query_embedding), k)

# Retrieve and print the results
print(f"Top {k} nearest sentences:")
for i in range(k):
    bunched_sentence = " ".join(chunks[I[0][i]])
    print(f"Sentence {i+1}: {chunks[I[0][i]]}, Distance: {D[0][i]}")
    print("__________"*20)
# Out:
# Top 5 nearest sentences:
# Sentence 1: . Order Management Service (E -commerce)
# Description : A service to create an order, track its status, and manage order updates, Distance: 0.1942642629146576
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# Sentence 2: . Inventory Management Service (Retail)
# Description : A service to track product inventory, update stock levels, and manage suppliers, Distance: 0.7188897132873535
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# Sentence 3: .
# Key Requirements :
# • Create Order : Accept user details, product list, and payment information, Distance: 0.9512720108032227
# ...

# %%
# # Function to generate response from Gemini Turbo
# def get_response(prompt, model="gemini"):
#   client = genai.GenerativeModel()
#   response = client.chat.completions.create(
#     model=model,
#     messages=[{"role": "system", "content": "You are a helpful assistant."},
#      {"role": "user", "content": f"{prompt}"}
#               ]
#   )
#   return response.choices[0].message.content

# %%
# !pip install -q -U google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.0/760.0 kB 20.1 MB/s eta 0:00:00

# %%
# Import the Python SDK
import google.generativeai as genai
# Used to securely store your API key
from google.colab import userdata

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('models/gemini-1.5-pro-latest')

# %%
def get_response_gemini(prompt, model="models/gemini-1.5-pro-latest"):
    api_key = os.getenv("GOOGLE_API_KEY")  # Get your API key from environment variables
    GEMINI_API_URL = "https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-pro-latest:generateText"  # Ensure this URL is correct

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }

    # Prepare the request data
    data = {
        "prompt": prompt,
        "max_tokens": 150,  # Adjust based on your needs
        "temperature": 0.7   # Adjust based on how creative you want the responses
    }

    # Send POST request to the Gemini API
    response = requests.post(GEMINI_API_URL, headers=headers, json=data)

    if response.status_code == 200:
        # Parse the response JSON and extract the generated text
        return response.json().get("text", "").strip()
    else:
        # Handle errors
        print(f"Error: Could not fetch response from Gemini API. Status Code: {response.status_code}")
        print(f"Response Content: {response.text}")  # Log the response content for debugging
        return f"Error: Could not fetch response from Gemini API. Status Code: {response.status_code}"

# %%
prefix = "Answer the question given the context."

# %%
prompt = f'''{prefix}\n\n\
                  Question: {question}\n\
                  Context: {bunched_sentence}\n\
                  Response: '''

# %%
# !pip install requests

# %%
import requests

def get_response_gemini(prompt, model="models/gemini-1.5-pro-latest"):
    pass

# %%
# !pip install google-auth requests

# %%
from urllib.parse import urlencode

client_id = "236466954990-5nf03pcikv9rlurjb4n3ermitn012kk6.apps.googleusercontent.com"
redirect_uri = "http://localhost:5000/callback"
scopes = ["https://www.googleapis.com/auth/gemini"]  # Use the appropriate scope

auth_url = "https://accounts.google.com/o/oauth2/v2/auth"
params = {
    "client_id": client_id,
    "redirect_uri": redirect_uri,
    "response_type": "code",
    "scope": " ".join(scopes),
    "access_type": "offline",  # To get a refresh token
    "prompt": "consent"
}

authorization_url = f"{auth_url}?{urlencode(params)}"
print("Visit this URL to authorize the application:", authorization_url)
# Out:
# Visit this URL to authorize the application: https://accounts.google.com/o/oauth2/v2/auth?client_id=236466954990-5nf03pcikv9rlurjb4n3ermitn012kk6.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A5000%2Fcallback&response_type=code&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgemini&access_type=offline&prompt=consent

# %%
import requests

# After redirect, you'll receive a code parameter
code = "AUTHORIZATION_CODE_RECEIVED_FROM_REDIRECT"

token_url = "https://oauth2.googleapis.com/token"
data = {
    "client_id": client_id,
    "client_secret": "YOUR_CLIENT_SECRET",
    "redirect_uri": redirect_uri,
    "grant_type": "authorization_code",
    "code": code
}

response = requests.post(token_url, data=data)
token_info = response.json()
access_token = token_info.get("access_token")
refresh_token = token_info.get("refresh_token")  # Save this for later use
print("Access Token:", access_token)
# Out:
# Access Token: None

# %%
def generate_response_gemini(prompt):
    api_url = "https://oauth2.googleapis.com/token"  # Replace with the actual API endpoint
    headers = {
        "Authorization": f"Bearer {access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "model": "models/gemini-1.5-pro-latest",
        "prompt": prompt,
        "max_tokens": 150,
        "temperature": 0.7
    }

    response = requests.post(api_url, headers=headers, json=data)
    if response.status_code == 200:
        return response.json().get("text", "").strip()
    else:
        return f"Error: Could not fetch response from Gemini API. Status Code: {response.status_code}, Response Content: {response.content}"

# Example usage
prompt = "Generate a backend service in Python for managing orders in an e-commerce platform."
response = generate_response_gemini(prompt)
print("Gemini API Response:", response)
# Out:
# Gemini API Response: Error: Could not fetch response from Gemini API. Status Code: 400, Response Content: b'{\n  "error": "unsupported_grant_type",\n  "error_description": "Invalid grant_type: "\n}'
